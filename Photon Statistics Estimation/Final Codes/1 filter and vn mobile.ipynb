# %%
# New Section
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/DC_Folder/1 filter and vn mobile.csv',  names=['y','x'])
df.head()
sample=df
np_X=np.array(sample['x'])
plt.hist(np_X,bins=[0,10,20,30,40,50,60,70])
# Out:
# (array([    0.,   583., 12565., 26679., 21090.,  8670.,  2202.]),
#  array([ 0., 10., 20., 30., 40., 50., 60., 70.]),
#  <BarContainer object of 7 artists>)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
w=10.0
while(w>=1):
  plt.hist(np_X, edgecolor='black', bins=np.arange(min(np_X), max(np_X) + w, w))
  plt.title("Histogram with bin-size = %i " %w)
  plt.show()
  w=w/2

# %% [markdown]
# ## Normalizing the data

# %%
# Import Standard Scaler from scikit-learn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
X = np.array(sample['x'])
y = np.array(sample['y'])

# %%
# StandardScaler().fit_transform(X.reshape(-1,1))
X = StandardScaler().fit_transform(X.reshape(-1,1))

# %%
X = X.reshape(-1,1)

# %%
plt.hist(X, edgecolor='black', bins=np.arange(min(X), max(X) + 0.5, 0.5))
# Out:
# (array([4.9421e+04, 2.3903e+04, 9.5990e+03, 6.3830e+03, 4.6800e+03,
#         1.2120e+03, 8.0000e+02, 6.3500e+02, 6.2000e+02, 1.3030e+03,
#         1.2520e+03, 1.8800e+02, 4.0000e+00]),
#  array([-0.89883022, -0.39883022,  0.10116978,  0.60116978,  1.10116978,
#          1.60116978,  2.10116978,  2.60116978,  3.10116978,  3.60116978,
#          4.10116978,  4.60116978,  5.10116978,  5.60116978]),
#  <BarContainer object of 13 artists>)

# %% [markdown]
# As we can see from above that on normalizing our dataset, our distribution obtained is similar to that of an exponential distribution

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate x values
x = np.linspace(0, 5, 100)  # Creating 100 points from 0 to 5

# Calculate y values
y = np.exp(-x)

# Create the plot
plt.plot(x, y)

# Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph of y = e^(-x)')

# Show the plot
plt.grid(True)
plt.show()
